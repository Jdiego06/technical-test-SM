# %%
import pandas as pd

# %%
interactions = pd.read_csv('./data/RAW_interactions.csv', parse_dates=[2])
users = pd.read_csv('./data/PP_users.csv', index_col='u')
recipes = pd.read_csv('./data/RAW_recipes.csv', parse_dates=[4], index_col='id')

# %%
interactions.head()
# Out:
#    user_id  recipe_id       date  rating  \
# 0    38094      40893 2003-02-17       4
# 1  1293707      40893 2011-12-21       5
# 2     8937      44394 2002-12-01       4
# 3   126440      85009 2010-02-27       5
# 4    57222      85009 2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
interactions.dtypes
# Out:
# user_id               int64
# recipe_id             int64
# date         datetime64[ns]
# rating                int64
# review               object
# dtype: object

# %%
users.dtypes
# Out:
# u              int64
# techniques    object
# items         object
# n_items        int64
# ratings       object
# n_ratings      int64
# dtype: object

# %%
recipes.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# tags                      object
# nutrition                 object
# n_steps                    int64
# steps                     object
# description               object
# ingredients               object
# n_ingredients              int64
# dtype: object

# %%
recipes.head()
# Out:
#                                               name  minutes  contributor_id  \
# id
# 137739  arriba   baked winter squash mexican style       55           47892
# 31490             a bit different  breakfast pizza       30           26278
# 112140                   all in the kitchen  chili      130          196586
# 59389                           alouette  potatoes       45           68585
# 44061           amish  tomato ketchup  for canning      190           41706
#
#         submitted                                               tags  \
# id
# 137739 2005-09-16  ['60-minutes-or-less', 'time-to-make', 'course...
# 31490  2002-06-17  ['30-minutes-or-less', 'time-to-make', 'course...
# 112140 2005-02-25  ['time-to-make', 'course', 'preparation', 'mai...
# 59389  2003-04-14  ['60-minutes-or-less', 'time-to-make', 'course...
# 44061  2002-10-25  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                          nutrition  n_steps  \
# id
# ...

# %%
users.head()
# Out:
#                                           techniques  \
# u
# 0  [8, 0, 0, 5, 6, 0, 0, 1, 0, 9, 1, 0, 0, 0, 1, ...
# 1  [11, 0, 0, 2, 12, 0, 0, 0, 0, 14, 5, 0, 0, 0, ...
# 2  [13, 0, 0, 7, 5, 0, 1, 2, 1, 11, 0, 1, 0, 0, 1...
# 3  [498, 13, 4, 218, 376, 3, 2, 33, 16, 591, 10, ...
# 4  [161, 1, 1, 86, 93, 0, 0, 11, 2, 141, 0, 16, 0...
#
#                                                items  n_items  \
# u
# 0  [1118, 27680, 32541, 137353, 16428, 28815, 658...       31
# 1  [122140, 77036, 156817, 76957, 68818, 155600, ...       39
# 2  [168054, 87218, 35731, 1, 20475, 9039, 124834,...       27
# 3  [163193, 156352, 102888, 19914, 169438, 55772,...     1513
# 4  [72857, 38652, 160427, 55772, 119999, 141777, ...      376
#
#                                              ratings  n_ratings
# u
# 0  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, ...         31
# 1  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...         39
# 2  [3.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 5.0, ...         27
# ...

# %%
recipes.loc[[27680]]
# Out:
#            name  minutes  contributor_id  submitted  \
# id
# 27680  lime tea       15           37779 2002-05-08
#
#                                                     tags  \
# id
# 27680  ['15-minutes-or-less', 'time-to-make', 'course...
#
#                                       nutrition  n_steps  \
# id
# 27680  [414.7, 0.0, 414.0, 0.0, 0.0, 0.0, 35.0]        7
#
#                                                    steps  \
# id
# 27680  ['pour 5 cups boiling water over tea bags', 'c...
#
#                                              description  \
# id
# 27680  love this so much. great summertime drink. add...
#
#                                              ingredients  n_ingredients
# id
# 27680  ['boiling water', 'tea bags', 'sugar', 'frozen...              4

# %%
interactions.loc[interactions.recipe_id ==27680]
# Out:
#         user_id  recipe_id       date  rating  \
# 868777    39277      27680 2002-05-14       5
# 868778    38643      27680 2002-05-18       5
# 868779    39733      27680 2002-05-23       5
# 868780    43005      27680 2002-06-08       5
# 868781    38810      27680 2002-06-12       5
# 868782    27643      27680 2002-06-17       5
# 868783    47230      27680 2002-07-10       5
# 868784    47847      27680 2002-07-25       4
# 868785    49360      27680 2002-08-06       5
# 868786    72112      27680 2003-05-27       5
# 868787    72963      27680 2003-06-12       5
# 868788    65059      27680 2003-06-14       5
# 868789    68942      27680 2003-06-19       0
# 868790     6550      27680 2003-06-24       5
# 868791    27707      27680 2003-07-12       5
# 868792    56392      27680 2004-01-11       4
# 868793    64683      27680 2005-06-21       4
# 868794   128473      27680 2009-02-15       5
# 868795   455641      27680 2010-01-17       5
# ...

# %%
users.loc[[0]]
# Out:
#                                           techniques  \
# u
# 0  [8, 0, 0, 5, 6, 0, 0, 1, 0, 9, 1, 0, 0, 0, 1, ...
#
#                                                items  n_items  \
# u
# 0  [1118, 27680, 32541, 137353, 16428, 28815, 658...       31
#
#                                              ratings  n_ratings
# u
# 0  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, ...         31

# %%
recipe = recipes.iloc[23222]
tags_list = [x[1:-1] for x in recipe.tags[1:-1].split(', ')]
tags_list
# Out:
# ['time-to-make',
#  'course',
#  'preparation',
#  'for-1-or-2',
#  'breads',
#  'dietary',
#  'number-of-servings',
#  '4-hours-or-less']
